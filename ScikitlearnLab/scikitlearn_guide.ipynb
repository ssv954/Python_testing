# %% [markdown]
# ## Day 3
#
# #### Install Scikit-Learn

# %%
# !pip install scikit-learn
# Out:
# ...
#                                               0.0/9.2 MB ? eta -:--:--
#      --                                       0.6/9.2 MB 18.2 MB/s eta 0:00:01
#      ------                                   1.6/9.2 MB 20.5 MB/s eta 0:00:01
#      -----------                              2.7/9.2 MB 21.1 MB/s eta 0:00:01
#      ---------------                          3.6/9.2 MB 21.1 MB/s eta 0:00:01
#      ----------------                         3.9/9.2 MB 19.0 MB/s eta 0:00:01
#      -----------------                        4.0/9.2 MB 16.0 MB/s eta 0:00:01
#      ------------------                       4.3/9.2 MB 13.6 MB/s eta 0:00:01
#      -------------------                      4.4/9.2 MB 12.3 MB/s eta 0:00:01
#      -------------------                      4.6/9.2 MB 11.7 MB/s eta 0:00:01
#      --------------------                     4.7/9.2 MB 10.8 MB/s eta 0:00:01
#      ---------------------                    4.9/9.2 MB 10.1 MB/s eta 0:00:01
# ...

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.3.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: d:\Document\Programer\Python Training\Projects\Python_testing\env\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import Dataset from Scikit Learn

# %%
from sklearn import datasets
import pandas as pd

dir(datasets.load_iris())

iris_dataset = datasets.load_iris()                                                     # load iris dataset
# digit_dataset = datasets.load_digit()                                                     # load iris dataset

# load data to pandas dataframe
dfiris = pd.DataFrame(data=iris_dataset.data, columns=iris_dataset.feature_names)
# dfdigit = pd.DataFrame(data=digit_dataset.data)
dfiris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #### Divide data for Train and Test

# %%
from sklearn.datasets import load_iris

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    iris_dataset['data'],
    iris_dataset['target'],
    random_state=0
    )

print('x_train shape {}' . format(x_train.shape))
print('x_test shape {}' . format(x_test.shape))
print('y_train shape {}' . format(y_train.shape))
print('y_test shape {}' . format(y_test.shape))
# Out:
# x_train shape (112, 4)
# x_test shape (38, 4)
# y_train shape (112,)
# y_test shape (38,)
